# %% [markdown]
# <a href="https://colab.research.google.com/github/kamangirkhan/Data110/blob/main/ArashNateghian_week3_data110_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the necessary libraries (Matplotlib and NumPy)

# %%
import matplotlib.pyplot as plt
import numpy as np

print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### 1. Setup and Styles
# Set the default style to 'seaborn-whitegrid'

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### 2. Basic Line Plot
# Create a plot of the quadratic function $f(x) = x^2 - 2x + 1$ over the range $[-2, 4]$

# %%
def f(x): return x**2 -2*x+1

x = np.linspace(-2, 4, 400)
y = f(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$f(x) = x^2 - 2x + 1$', color='b')

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title('Plot of $f(x) = x^2 - 2x + 1$')

plt.legend()
plt.show()

# %% [markdown]
# ### 3. Multiple Lines
# - Create a plot with the following three functions on the same graph:
#   - $f(x) = x^3$
#   - $g(x) = e^x$
#   - $h(x) = \log(x)$ (for $x > 0$)

# %%
def f(x): return x**3
def g(x): return np.exp(x)
def h(x): return np.log(x)

x = np.linspace (-2, 4, 400)
x_log = np.linspace(0.111, 4, 400)

y_f = f(x)
y_g = g(x)
y_h = h(x_log)

plt.figure(figsize=(8, 6))
plt.plot(x, y_f, label=r'$f(x) = x^3$', color='r')
plt.plot(x, y_g, label=r'$g(x) = e^x$', color='g')
plt.plot(x_log, y_h, label=r'$h(x) = \log(x)$', color='y')

plt.xlabel('X')
plt.ylabel('Functions')
plt.title('Plot of $f(x) = x^3$, $g(x) = e^x$, and $h(x) = \log(x)$')

plt.legend()
plt.show()

# %% [markdown]
# ### 4. Styling Lines
# - Create a plot with the following functions, each with a different color and line style:
#   - $f(x) = x^2$
#   - $g(x) = x^3$
#   - $h(x) = x^4$
#   - $i(x) = x^5$

# %%
def f(x): return x**2
def g(x): return x**3
def h(x): return x**4
def i(x): return x**5

x = np.linspace (-2, 2, 400)
y_f = f(x)
y_g = g(x)
y_h = h(x)
y_i = i(x)

plt.figure(figsize=(12, 8))
plt.plot(x, y_f, label=r'$f(x) = x^2$', color='r', linestyle='-')
plt.plot(x, y_g, label=r'$g(x) = x^3$', color='g', linestyle='--')
plt.plot(x, y_h, label=r'$h(x) = x^4$', color='y', linestyle='-.')
plt.plot(x, y_i, label=r'$h(x) = x^5$', color='b', linestyle=':')

plt.xlabel('X')
plt.ylabel('Functions')
plt.title('Plot of $f(x) = x^2$, $g(x) = x^3$, $h(x) = x^4$, and $i(x) = x^5$')

plt.legend()
plt.show()

# %% [markdown]
# ### 5. Axes Limits and Scaling
# - Plot the function $f(x) = \frac{1}{x^2 + 1}$ over the range $[-10, 10]$
# - Set appropriate custom x and y limits to showcase the function's behavior
# - Create another plot of the same function with reversed x and y axes
# - Demonstrate the use of `plt.axis('tight')` and `plt.axis('equal')`

# %%
def f(x):  return 1 / (x**2 + 1)

x = np.linspace(-10, 10, 400)
y = f(x)

#Plot with Reversed Axes
plt.figure(figsize=(8, 5))
plt.plot(y, x, label='Reversed Axes', color='r', linestyle='--')

plt.xlabel('f(x)')
plt.ylabel('x')
plt.title('Plot with Reversed Axes')
plt.xlim(0, 1.2)
plt.ylim(-10, 10)

plt.legend()
plt.show()

#Plot with 'equal' Aspect Ratio
plt.figure(figsize=(8, 5))
plt.plot(x, y, color='g', label='Equal Axis Scale')

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title("Plot with 'equal' Aspect Ratio")
plt.axis('equal')

plt.legend()
plt.show()

#Plot with 'tight' Aspect Ratio
plt.figure(figsize=(8, 5))
plt.plot(x, y, color='g', label='Tight Axis Scale')

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title("Plot with 'tight' Aspect Ratio")
plt.axis('tight')
plt.xlim(-10, 10)
plt.ylim(0, 1.2)

plt.legend()
plt.show()

# %% [markdown]
# ### 6. Labels and Legends
# - Create a plot of $f(x) = \sqrt{x}$ and $g(x) = x^{\frac{1}{3}}$ for $x \geq 0$
# - Add a proper title, x-label, y-label, and legend

# %%
def f(x): return np.sqrt(x)
def g(x): return np.cbrt(x)

x = np.linspace(0, 10 , 400)
y_f = f(x)
y_g = g(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y_f, label=r'$f(x)= \sqrt{x}$', color= 'r', linestyle= '--')
plt.plot(x, y_g, label=r'$g(x) = x^{\frac{1}{3}}$', color= 'k', linestyle= ':')

plt.xlabel('X')
plt.ylabel('Functions')
plt.title('Plot of $f(x) = \sqrt{x}$ and $g(x) = x^{1/3}$')

plt.legend()
plt.show()

# %% [markdown]
# ### 7. Basic Scatter Plot
# - Generate 50 random points using `np.random.rand()` for both x and y
# - Create a scatter plot of these points using `plt.plot()` with the 'o' marker
# - Create the same scatter plot using `plt.scatter()`

# %%
x = np.random.rand(50)
y = np.random.rand(50)

#Scatter using plt.plot()
plt.figure(figsize=(8, 5))
plt.plot(x, y, 'o', label= 'plt.plot()', color= 'b')

plt.title('Scatter using plt.plot()')
plt.xlabel('X')
plt.ylabel('Y')

plt.legend()
plt.show()

#Scatter using plt.scatter()
plt.figure(figsize=(8, 5))
plt.scatter(x, y, label='plt.scatter()', color= 'y')

plt.title('Scatter using plt.scatter()')
plt.xlabel('X')
plt.ylabel('Y')

plt.legend()
plt.show()

# %% [markdown]
# ### 8. Customizing Scatter Plots
# - Generate data for the function $f(x) = x \sin(x)$ over the range $[0, 4\pi]$
# - Create a scatter plot of this data with a line connecting the points
# - Customize the plot by changing the marker size, line width, marker face color, marker edge color, and marker edge width

# %%
def f(x): return x*np.sin(x)

x = np.linspace(0, 4*np.pi, 100)
y = f(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$line$', linestyle='-', color='b', linewidth=1)
plt.scatter(x, y, s=25, label='$points$', color='w', edgecolor='r', linewidth=1)

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title('$x \sin(x)$')

plt.legend()
plt.show()

# %% [markdown]
# ### 9. Combined Plot
# - Plot the function $f(x) = x \cos(x)$ over the range $[-2\pi, 2\pi]$
# - Add scatter points for x values at every $\frac{\pi}{4}$ interval
# - Use different colors and styles for the line and scatter components

# %%
def f(x): return x*np.cos(x)

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = f(x)

x_scatter = np.arange(-2*np.pi, 2*np.pi, np.pi/4)
y_scatter = x_scatter * np.cos(x_scatter)

plt.figure(figsize=(10, 8))
plt.plot(x, y, label=r'$line$', linestyle='--', color='b', linewidth=2)
plt.scatter(x_scatter, y_scatter, s=50, label="points" , color='red', edgecolor='black', linewidth=1.5)

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title('$x \cos(x)$')

plt.legend()
plt.show()

# %% [markdown]
# ### 10. Custom Plot with Alternative Style
# - Choose two or more functions from the following list:
#   - $f(x) = \tan(x)$
#   - $g(x) = x e^{-x^2}$
#   - $h(x) = \frac{\sin(x)}{x}$  (with appropriate handling for $x=0$)
#   - $i(x) = \arctan(x)$
#   - $j(x) = \frac{1}{1 + e^{-x}}$  (logistic function)
# - Create a custom plot that combines at least 4 concepts learned (e.g., multiple functions, scatter points, custom colors, line styles, limits, labels, and legend)
# - Use the alternative style you chose in Task 1 for this plot
# - Add comments explaining your choices, the significance of the functions you chose, and how the alternative style affects the plot's appearance

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')

x = np.linspace(-5, 5, 400)
g_x = x * np.exp(-x**2)
j_x = 1 / (1 + np.exp(-x))

x_scatter = np.arange(-5, 5, 1)
y_scatter_g = x_scatter * np.exp(-x_scatter**2)
y_scatter_j = 1 / (1 + np.exp(-x_scatter))

plt.figure(figsize=(12, 8))
plt.scatter(x_scatter, y_scatter_g, color='blue', edgecolor='black', s=50, label="g(x) Key Points")
plt.scatter(x_scatter, y_scatter_j, color='orange', edgecolor='black', s=50, label="j(x) Key Points")

plt.plot(x, g_x, linestyle='--', color='b', linewidth=2, label='$g(x) = x e^{-x^2}$')
plt.plot(x, j_x, linestyle='-', color='orange', linewidth=2, label=r'$j(x) = \frac{1}{1+e^{-x}}$')

plt.xlim(-5, 5)
plt.ylim(-1.5, 1.5)
plt.xlabel("X")
plt.ylabel("Functions")
plt.title(r'Plot of $g(x) = \sqrt{x}$ and $j(x) = \frac{1}{1+e^{-x}}$')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2*np.pi, 2*np.pi, 400)
f_x = np.tan(x)
h_x = np.where(x == 0, 1, np.sin(x) / x)
i_x = np.arctan(x)

x_scatter = np.arange(-2*np.pi, 2*np.pi, np.pi/6)
y_scatter_f = np.tan(x_scatter)
y_scatter_h = np.sinc(x_scatter / np.pi)
y_scatter_i = np.arctan(x_scatter)

plt.figure(figsize=(12, 8))

plt.plot(x, f_x, linestyle='-', color='purple', linewidth=2, label=r'$f(x) = \tan(x)$')
plt.plot(x, h_x, linestyle='-.', color='r', linewidth=2, label=r'$h(x) = \frac{\sin(x)}{x}$')
plt.plot(x, i_x, linestyle=':', color='g', linewidth=2, label=r'$i(x) = \arctan(x)$')

plt.scatter(x_scatter, y_scatter_f, color='b', edgecolor='k', s=50, label="f(x) Key Points")
plt.scatter(x_scatter, y_scatter_h, color='r', edgecolor='k', s=50, label="h(x) Key Points")
plt.scatter(x_scatter, y_scatter_i, color='g', edgecolor='k', s=50, label="i(x) Key Points")

plt.xlim(-2*np.pi, 2*np.pi)
plt.ylim(-20, 20)
plt.xlabel("X")
plt.ylabel("Functions")
plt.title(r'Plot of $f(x) = \tan(x)$, $h(x) = \frac{\sin(x)}{x}$ and $i(x) = \arctan(x)$')

plt.legend()
plt.show()

# %% [markdown]
# ### 11. Style Comparison
# - Choose one of your previous plots (Tasks 2-9)
# - Recreate it using three different styles: the default style, 'seaborn-whitegrid', and your chosen alternative style
# - Compare and contrast the appearances, discussing which style might be most appropriate for the specific data being plotted

# %%
plt.style.use('default')

def f(x): return x**2 -2*x+1

x = np.linspace(-2, 4, 400)
y = f(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$f(x) = x^2 - 2x + 1$', color='b')

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title('Plot of $f(x) = x^2 - 2x + 1$')

plt.legend()
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')

def f(x): return x**2 -2*x+1

x = np.linspace(-2, 4, 400)
y = f(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$f(x) = x^2 - 2x + 1$', color='b')

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title('Plot of $f(x) = x^2 - 2x + 1$')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')

def f(x): return x**2 -2*x+1

x = np.linspace(-2, 4, 400)
y = f(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$f(x) = x^2 - 2x + 1$', color='b')

plt.xlabel('X')
plt.ylabel('f(x)')
plt.title('Plot of $f(x) = x^2 - 2x + 1$')

plt.legend()
plt.show()

# %% [markdown]
# | Style | Appearance | Best Use Case |
# |----------|----------|----------|
# | default | White Background, no Grid | Simple, Distraction-free Plots |
# | seaborn-v0_8-whitegrid | Light Background with Grid | Presentations and Data Analysis  |
# | ggplot | Dark Background, White Grid | Publication-Quality Visualizations |
