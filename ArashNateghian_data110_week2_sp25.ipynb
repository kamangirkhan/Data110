# %% [markdown]
# <a href="https://colab.research.google.com/github/kamangirkhan/Data110/blob/main/ArashNateghian_data110_week2_sp25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Reben80/Data110-32008--Sp25/refs/heads/main/dataset/happiness_2017.csv")
df=pd.read_csv("/content/happiness_2017.csv")

# %% [markdown]
# ### Assignment 1: Basic Scatter Plot
# Create a scatter plot showing the relationship between 'Log GDP per capita' and 'HappinessScore'.
# - Use appropriate axis labels
# - Add a title
# - Set figure size to (12,8)

# %%
# Assignment 1: Basic Scatter Plot

plt.figure(figsize=(12,8))
plt.scatter(df['Log GDP per capita'], df['HappinessScore'])
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.title("'Log GDP per capita' vs 'Happiness Score'")
plt.show()

# %% [markdown]
# ### Assignment 2: Styled Scatter Plot
# Create a scatter plot comparing 'Social support' vs 'Healthy life expectancy at birth'.
# - Use red markers with black edges
# - Set marker size to 100
# - Add a grid
# - Make markers semi-transparent (alpha=0.6)

# %%
# Assignment 2: Styled Scatter Plot

plt.figure(figsize=(12,8))
plt.scatter(df['Social support'], df['Healthy life expectancy at birth'],
            color='Red', marker='o', edgecolors='black', alpha=0.6, s=100)
plt.xlabel('Social support')
plt.ylabel('Healthy life expectancy at birth',)
plt.title("'Social support' vs 'Healthy life expectancy at birth'",)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Assignment 3: Advanced Visualization
# Create a scatter plot showing 'Freedom to make life choices' vs 'Positive affect'.
# - Use triangle markers ('^')
# - Make the plot blue with yellow edges
# - Add bold labels
# - Include a grid with dashed lines

# %%
# #Assignment 3: Advanced Visualization

plt.figure(figsize=(12,8))
plt.scatter(df['Freedom to make life choices'], df['Positive affect'], color='Blue', marker='^', edgecolors='Yellow')
plt.xlabel('Freedom to make life choices', fontweight='bold')
plt.ylabel('Positive affect', fontweight='bold')
plt.title("'Freedom to make life choices' vs 'Positive affect'", fontweight='bold')
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ### Bonus Challenge 🌟
# Create a scatter plot comparing any two variables of your choice, but:
# - Use a style from `plt.style.available`
# - Add custom font sizes for labels
# - Include a brief interpretation of what the plot shows

# %%
# Bonus Challenge 🌟

plt.style.available
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
plt.scatter(df['Freedom to make life choices'], df['Positive affect'])
plt.xlabel('Freedom to make life choices')
plt.ylabel('Positive affect')
plt.title("'Freedom to make life choices' vs 'Positive affect'")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.text(x=df['Freedom to make life choices'].max() -.33,
         y=df['Positive affect'].min(), s="Higher freedom levels tend to be associated with higher positive emotions")
plt.show()

# %% [markdown]
# ###  Anscombe's Quartet Dataset
#
# This dataset is known as **Anscombe's Quartet**, created by statistician Francis Anscombe to illustrate the importance of visualizing data. Despite having nearly identical statistical properties (e.g., mean, variance, correlation, and linear regression), each dataset tells a very different story when graphed.
#
# - **x**: The independent variable, common across three datasets.
# - **y1, y2, y3**: Three different dependent variables associated with the same `x` values.
# - **x4, y4**: A special case where most of the `x` values are identical, with one outlier.
#
# #### Anscombe's Quartet:

# %%
# Anscombe's Quartet:

x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
# Dataset 1: A typical linear relationship.

plt.scatter(x, y1, color='Red', marker='^', edgecolors='black', alpha=0.6, s=100)
plt.xlabel('x')
plt.ylabel('y1')
plt.title('(x, y1) Data Points')
plt.text(max(x) -4, min(y1), s="A typical linear relationship")
plt.show()

# %%
# A typical linear relationship with regression line
m, b = np.polyfit(x, y1, 1)
regression_line = m * np.array(x) + b
plt.scatter(x, y1, color='Red', marker='^', edgecolors='black', alpha=0.6, s=100)
plt.plot(x, regression_line,color='Black')
plt.xlabel('x')
plt.ylabel('y1')
plt.title('(x, y1) Data Points and Regression Line')
plt.text(max(x) -7, min(y1), s="A typical linear relationship with regression line")
plt.show()

# %%
# Dataset 2: A non-linear relationship

plt.scatter(x, y2, color='Blue', marker='o', alpha=0.6, s=50)
plt.xlabel('x')
plt.ylabel('y2')
plt.title('(x, y2) Data Points')
plt.text(max(x) -3.5, min(y2), s="A non-linear relationship")
plt.show()

# %%
# A non-linear relationship with regression line
m, b = np.polyfit(x, y2, 1)
regression_line = m * np.array(x) + b
plt.scatter(x, y2, color='Blue', marker='o', alpha=0.6, s=50)
plt.plot(x, regression_line,color='Orange')
plt.xlabel('x')
plt.ylabel('y2')
plt.title('(x, y2) Data Points and Regression Line')
plt.text(max(x) -6.5, min(y2), s="A non-linear relationship with regression line")
plt.show()

# %%
# Dataset 3: A dataset with an outlier

plt.scatter(x, y3, color='Green', marker='x', alpha=0.6, s=50)
plt.xlabel('x')
plt.ylabel('y3')
plt.title('(x, y3) Data Points')
plt.text(max(x) -3.5, min(y3), s="A dataset with an outlier")
plt.show()

# %%
# A dataset with an outlier with regression line
m, b = np.polyfit(x, y3, 1)
regression_line = m * np.array(x) + b

plt.scatter(x, y3, color='Green', marker='x', alpha=0.6, s=50)
plt.plot(x, regression_line,color='yellow')
plt.xlabel('x')
plt.ylabel('y3')
plt.title('(x, y3) Data Points and Regression Line')
plt.text(max(x) -6.5, min(y1) +.5, s="A dataset with an outlier with regression line")
plt.show()

# %%
# Dataset 4: A vertical pattern caused by a single influential point

plt.style.available
plt.style.use('ggplot')
plt.scatter(x4, y4)
plt.xlabel('x4')
plt.ylabel('y4')
plt.title('(x4, y4) Data Points')
plt.text(max(x) -4, min(y1) +1, s="A vertical pattern caused by a single influential point")
plt.show()

# %%
# A vertical pattern caused by a single influential point with regression line

plt.style.available
plt.style.use('ggplot')
m, b = np.polyfit(x4, y4, 1)
regression_line = m * np.array(x) + b
plt.scatter(x4, y4)
plt.plot(x4, regression_line,color='blue')
plt.xlabel('x4')
plt.ylabel('y4')
plt.title('(x4, y4) Data Points and Regression Line')
plt.text(min(x) +4, max(y1) +1, s="A vertical pattern caused by a single influential point\n"
"with regression line")
plt.show()
